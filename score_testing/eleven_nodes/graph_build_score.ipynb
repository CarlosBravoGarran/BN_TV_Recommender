# %% [markdown]
# ### Setup inicial

# %%
# Librerías básicas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx

# Librerías BN
from pgmpy.models import DiscreteBayesianNetwork
from pgmpy.estimators import HillClimbSearch, BIC, K2, BDeu
from pgmpy.estimators import BayesianEstimator, MaximumLikelihoodEstimator
from pgmpy.readwrite import BIFWriter

# Configuración general
pd.set_option("display.max_columns", None)
plt.rcParams["figure.figsize"] = (8, 6)

print("✅ Librerías cargadas")
# Out:
# ✅ Librerías cargadas

# %% [markdown]
# ### Cargar y preparar datos

# %%
# Cargar dataset
data = pd.read_csv("tv_bn_dataset.csv")

# Convertir todas las variables a categóricas (importante para BN)
for c in data.columns:
    data[c] = data[c].astype("category")

print("✅ Datos cargados y convertidos a categóricos")
display(data.head())
# Out:
# ✅ Datos cargados y convertidos a categóricos
#   GeneroUsuario EdadUsuario    Hora   DiaSemana DuracionPrograma  \
# 0        hombre       joven   noche     laboral            corta
# 1        hombre       mayor  mañana     laboral            corta
# 2        hombre      adulto   tarde  fin_semana            corta
# 3         mujer      adulto   tarde     laboral            corta
# 4        hombre       joven   tarde     laboral            corta
#
#     TipoEmision    InteresPrevio   GeneroPrograma PopularidadPrograma  \
# 0  bajo_demanda         noticias         noticias                baja
# 1      diferido         noticias  entretenimiento                alta
# 2  bajo_demanda         noticias         noticias                baja
# 3       directo         película         película                baja
# 4       directo  entretenimiento         noticias                baja
#
#   Satisfaccion Recomendado
# 0        media          sí
# 1         baja          no
# 2         alta          no
# 3         alta          no
# 4         alta          no

# %% [markdown]
# ### Comparar métodos de scoring

# %% [markdown]
# #### 1. BIC (Bayesian Information Criterion)

# %%
hc = HillClimbSearch(data)
best_model = hc.estimate(scoring_method=BIC(data))
print("✅ Modelo aprendido con BIC")

model = DiscreteBayesianNetwork(best_model.edges())
model.fit(data, estimator=BayesianEstimator)
print("✅ Modelo entrenado con BIC")

# Convertir a un grafo de networkx y visualizar la estructura del modelo
G = nx.DiGraph()
G.add_nodes_from(model.nodes())
G.add_edges_from(model.edges())

plt.figure(figsize=(10, 8))
pos = nx.spring_layout(G, seed=42)
nx.draw(G, pos, with_labels=True, node_size=1000, node_color="lightblue", font_size=10, font_weight="bold", arrowsize=20)
plt.title("BIC")
plt.show()
# Out:
# INFO:pgmpy: Datatype (N=numerical, C=Categorical Unordered, O=Categorical Ordered) inferred from data:
#  {'GeneroUsuario': 'C', 'EdadUsuario': 'C', 'Hora': 'C', 'DiaSemana': 'C', 'DuracionPrograma': 'C', 'TipoEmision': 'C', 'InteresPrevio': 'C', 'GeneroPrograma': 'C', 'PopularidadPrograma': 'C', 'Satisfaccion': 'C', 'Recomendado': 'C'}
# INFO:pgmpy: Datatype (N=numerical, C=Categorical Unordered, O=Categorical Ordered) inferred from data:
#  {'GeneroUsuario': 'C', 'EdadUsuario': 'C', 'Hora': 'C', 'DiaSemana': 'C', 'DuracionPrograma': 'C', 'TipoEmision': 'C', 'InteresPrevio': 'C', 'GeneroPrograma': 'C', 'PopularidadPrograma': 'C', 'Satisfaccion': 'C', 'Recomendado': 'C'}
# INFO:pgmpy: Datatype (N=numerical, C=Categorical Unordered, O=Categorical Ordered) inferred from data:
#  {'GeneroUsuario': 'C', 'EdadUsuario': 'C', 'Hora': 'C', 'DiaSemana': 'C', 'DuracionPrograma': 'C', 'TipoEmision': 'C', 'InteresPrevio': 'C', 'GeneroPrograma': 'C', 'PopularidadPrograma': 'C', 'Satisfaccion': 'C', 'Recomendado': 'C'}
#   0%|          | 0/1000000 [00:00<?, ?it/s]
# INFO:pgmpy: Datatype (N=numerical, C=Categorical Unordered, O=Categorical Ordered) inferred from data:
#  {'GeneroUsuario': 'C', 'EdadUsuario': 'C', 'Hora': 'C', 'DiaSemana': 'C', 'DuracionPrograma': 'C', 'TipoEmision': 'C', 'InteresPrevio': 'C', 'GeneroPrograma': 'C', 'PopularidadPrograma': 'C', 'Satisfaccion': 'C', 'Recomendado': 'C'}
# ✅ Modelo aprendido con BIC
# ✅ Modelo entrenado con BIC

# %% [markdown]
# #### 2. K2

# %%
hc = HillClimbSearch(data)
best_model_K2 = hc.estimate(scoring_method=K2(data))
print("✅ Modelo aprendido con K2")


model_K2 = DiscreteBayesianNetwork(best_model_K2.edges())
model_K2.fit(data, estimator=BayesianEstimator)
print("✅ Modelo entrenado con K2")

# Convertir a un grafo de networkx y visualizar la estructura del modelo
G_K2 = nx.DiGraph()
G_K2.add_nodes_from(model_K2.nodes())
G_K2.add_edges_from(model_K2.edges())

plt.figure(figsize=(10, 8))
pos = nx.spring_layout(G_K2, seed=42)
nx.draw(G_K2, pos, with_labels=True, node_size=1000, node_color="lightblue", font_size=10, font_weight="bold", arrowsize=20)
plt.title("K2")
plt.show()
# Out:
# INFO:pgmpy: Datatype (N=numerical, C=Categorical Unordered, O=Categorical Ordered) inferred from data:
#  {'GeneroUsuario': 'C', 'EdadUsuario': 'C', 'Hora': 'C', 'DiaSemana': 'C', 'DuracionPrograma': 'C', 'TipoEmision': 'C', 'InteresPrevio': 'C', 'GeneroPrograma': 'C', 'PopularidadPrograma': 'C', 'Satisfaccion': 'C', 'Recomendado': 'C'}
# INFO:pgmpy: Datatype (N=numerical, C=Categorical Unordered, O=Categorical Ordered) inferred from data:
#  {'GeneroUsuario': 'C', 'EdadUsuario': 'C', 'Hora': 'C', 'DiaSemana': 'C', 'DuracionPrograma': 'C', 'TipoEmision': 'C', 'InteresPrevio': 'C', 'GeneroPrograma': 'C', 'PopularidadPrograma': 'C', 'Satisfaccion': 'C', 'Recomendado': 'C'}
# INFO:pgmpy: Datatype (N=numerical, C=Categorical Unordered, O=Categorical Ordered) inferred from data:
#  {'GeneroUsuario': 'C', 'EdadUsuario': 'C', 'Hora': 'C', 'DiaSemana': 'C', 'DuracionPrograma': 'C', 'TipoEmision': 'C', 'InteresPrevio': 'C', 'GeneroPrograma': 'C', 'PopularidadPrograma': 'C', 'Satisfaccion': 'C', 'Recomendado': 'C'}
#   0%|          | 0/1000000 [00:00<?, ?it/s]
# INFO:pgmpy: Datatype (N=numerical, C=Categorical Unordered, O=Categorical Ordered) inferred from data:
#  {'GeneroUsuario': 'C', 'EdadUsuario': 'C', 'Hora': 'C', 'DiaSemana': 'C', 'DuracionPrograma': 'C', 'TipoEmision': 'C', 'InteresPrevio': 'C', 'GeneroPrograma': 'C', 'PopularidadPrograma': 'C', 'Satisfaccion': 'C', 'Recomendado': 'C'}
# ✅ Modelo aprendido con K2
# ✅ Modelo entrenado con K2

# %% [markdown]
# #### 3. BDeu (Bayesian Dirichlet equivalent uniform)

# %%
ess_list = [1, 5, 10, 50, 100, 500]

for ess in ess_list:
    print(f"--- equivalent_sample_size = {ess} ---")
    best_model_BDeu = hc.estimate(scoring_method=BDeu(data, equivalent_sample_size=ess))
    print("Edges:", list(best_model_BDeu.edges()))
    
    model_BDeu = DiscreteBayesianNetwork(best_model_BDeu.edges())
    model_BDeu.fit(data, estimator=BayesianEstimator)
    
    # Grafo y visualización (usa pos si ya existe para mantener la disposición)
    G_BDeu = nx.DiGraph()
    G_BDeu.add_nodes_from(model_BDeu.nodes())
    G_BDeu.add_edges_from(model_BDeu.edges())

    plt.figure(figsize=(10, 8))
    layout = pos if 'pos' in globals() else nx.spring_layout(G_BDeu, seed=42)
    nx.draw(G_BDeu, layout, with_labels=True, node_size=1000, node_color="lightblue",
            font_size=10, font_weight="bold", arrowsize=20)
    plt.title(f"BDeu (ess={ess})")
    plt.show()
# Out:
# INFO:pgmpy: Datatype (N=numerical, C=Categorical Unordered, O=Categorical Ordered) inferred from data:
#  {'GeneroUsuario': 'C', 'EdadUsuario': 'C', 'Hora': 'C', 'DiaSemana': 'C', 'DuracionPrograma': 'C', 'TipoEmision': 'C', 'InteresPrevio': 'C', 'GeneroPrograma': 'C', 'PopularidadPrograma': 'C', 'Satisfaccion': 'C', 'Recomendado': 'C'}
# INFO:pgmpy: Datatype (N=numerical, C=Categorical Unordered, O=Categorical Ordered) inferred from data:
#  {'GeneroUsuario': 'C', 'EdadUsuario': 'C', 'Hora': 'C', 'DiaSemana': 'C', 'DuracionPrograma': 'C', 'TipoEmision': 'C', 'InteresPrevio': 'C', 'GeneroPrograma': 'C', 'PopularidadPrograma': 'C', 'Satisfaccion': 'C', 'Recomendado': 'C'}
# --- equivalent_sample_size = 1 ---
#   0%|          | 0/1000000 [00:00<?, ?it/s]
# INFO:pgmpy: Datatype (N=numerical, C=Categorical Unordered, O=Categorical Ordered) inferred from data:
#  {'GeneroUsuario': 'C', 'EdadUsuario': 'C', 'Hora': 'C', 'DiaSemana': 'C', 'DuracionPrograma': 'C', 'TipoEmision': 'C', 'InteresPrevio': 'C', 'GeneroPrograma': 'C', 'PopularidadPrograma': 'C', 'Satisfaccion': 'C', 'Recomendado': 'C'}
# Edges: [('GeneroUsuario', 'EdadUsuario'), ('Hora', 'TipoEmision'), ('DiaSemana', 'TipoEmision'), ('TipoEmision', 'InteresPrevio'), ('TipoEmision', 'GeneroPrograma'), ('InteresPrevio', 'EdadUsuario'), ('InteresPrevio', 'GeneroUsuario'), ('GeneroPrograma', 'InteresPrevio'), ('GeneroPrograma', 'PopularidadPrograma'), ('GeneroPrograma', 'DuracionPrograma'), ('PopularidadPrograma', 'Recomendado'), ('PopularidadPrograma', 'Satisfaccion'), ('Satisfaccion', 'Recomendado'), ('Satisfaccion', 'InteresPrevio')]
# INFO:pgmpy: Datatype (N=numerical, C=Categorical Unordered, O=Categorical Ordered) inferred from data:
#  {'GeneroUsuario': 'C', 'EdadUsuario': 'C', 'Hora': 'C', 'DiaSemana': 'C', 'DuracionPrograma': 'C', 'TipoEmision': 'C', 'InteresPrevio': 'C', 'GeneroPrograma': 'C', 'PopularidadPrograma': 'C', 'Satisfaccion': 'C', 'Recomendado': 'C'}
# INFO:pgmpy: Datatype (N=numerical, C=Categorical Unordered, O=Categorical Ordered) inferred from data:
#  {'GeneroUsuario': 'C', 'EdadUsuario': 'C', 'Hora': 'C', 'DiaSemana': 'C', 'DuracionPrograma': 'C', 'TipoEmision': 'C', 'InteresPrevio': 'C', 'GeneroPrograma': 'C', 'PopularidadPrograma': 'C', 'Satisfaccion': 'C', 'Recomendado': 'C'}
# --- equivalent_sample_size = 5 ---
#   0%|          | 0/1000000 [00:00<?, ?it/s]
# INFO:pgmpy: Datatype (N=numerical, C=Categorical Unordered, O=Categorical Ordered) inferred from data:
#  {'GeneroUsuario': 'C', 'EdadUsuario': 'C', 'Hora': 'C', 'DiaSemana': 'C', 'DuracionPrograma': 'C', 'TipoEmision': 'C', 'InteresPrevio': 'C', 'GeneroPrograma': 'C', 'PopularidadPrograma': 'C', 'Satisfaccion': 'C', 'Recomendado': 'C'}
# Edges: [('GeneroUsuario', 'EdadUsuario'), ('DiaSemana', 'Hora'), ('DuracionPrograma', 'TipoEmision'), ('TipoEmision', 'Hora'), ('TipoEmision', 'DiaSemana'), ('InteresPrevio', 'EdadUsuario'), ('InteresPrevio', 'GeneroUsuario'), ('InteresPrevio', 'TipoEmision'), ('GeneroPrograma', 'InteresPrevio'), ('GeneroPrograma', 'TipoEmision'), ('GeneroPrograma', 'DuracionPrograma'), ('PopularidadPrograma', 'GeneroPrograma'), ('Satisfaccion', 'PopularidadPrograma'), ('Satisfaccion', 'InteresPrevio'), ('Recomendado', 'Satisfaccion'), ('Recomendado', 'PopularidadPrograma')]
# INFO:pgmpy: Datatype (N=numerical, C=Categorical Unordered, O=Categorical Ordered) inferred from data:
#  {'GeneroUsuario': 'C', 'EdadUsuario': 'C', 'Hora': 'C', 'DiaSemana': 'C', 'DuracionPrograma': 'C', 'TipoEmision': 'C', 'InteresPrevio': 'C', 'GeneroPrograma': 'C', 'PopularidadPrograma': 'C', 'Satisfaccion': 'C', 'Recomendado': 'C'}
# INFO:pgmpy: Datatype (N=numerical, C=Categorical Unordered, O=Categorical Ordered) inferred from data:
#  {'GeneroUsuario': 'C', 'EdadUsuario': 'C', 'Hora': 'C', 'DiaSemana': 'C', 'DuracionPrograma': 'C', 'TipoEmision': 'C', 'InteresPrevio': 'C', 'GeneroPrograma': 'C', 'PopularidadPrograma': 'C', 'Satisfaccion': 'C', 'Recomendado': 'C'}
# --- equivalent_sample_size = 10 ---
#   0%|          | 0/1000000 [00:00<?, ?it/s]
# INFO:pgmpy: Datatype (N=numerical, C=Categorical Unordered, O=Categorical Ordered) inferred from data:
#  {'GeneroUsuario': 'C', 'EdadUsuario': 'C', 'Hora': 'C', 'DiaSemana': 'C', 'DuracionPrograma': 'C', 'TipoEmision': 'C', 'InteresPrevio': 'C', 'GeneroPrograma': 'C', 'PopularidadPrograma': 'C', 'Satisfaccion': 'C', 'Recomendado': 'C'}
# Edges: [('GeneroUsuario', 'EdadUsuario'), ('Hora', 'TipoEmision'), ('DiaSemana', 'TipoEmision'), ('DuracionPrograma', 'GeneroPrograma'), ('TipoEmision', 'InteresPrevio'), ('TipoEmision', 'GeneroPrograma'), ('InteresPrevio', 'EdadUsuario'), ('InteresPrevio', 'GeneroUsuario'), ('GeneroPrograma', 'InteresPrevio'), ('GeneroPrograma', 'PopularidadPrograma'), ('PopularidadPrograma', 'Satisfaccion'), ('PopularidadPrograma', 'Recomendado'), ('Satisfaccion', 'InteresPrevio'), ('Recomendado', 'Satisfaccion')]
# INFO:pgmpy: Datatype (N=numerical, C=Categorical Unordered, O=Categorical Ordered) inferred from data:
#  {'GeneroUsuario': 'C', 'EdadUsuario': 'C', 'Hora': 'C', 'DiaSemana': 'C', 'DuracionPrograma': 'C', 'TipoEmision': 'C', 'InteresPrevio': 'C', 'GeneroPrograma': 'C', 'PopularidadPrograma': 'C', 'Satisfaccion': 'C', 'Recomendado': 'C'}
# INFO:pgmpy: Datatype (N=numerical, C=Categorical Unordered, O=Categorical Ordered) inferred from data:
#  {'GeneroUsuario': 'C', 'EdadUsuario': 'C', 'Hora': 'C', 'DiaSemana': 'C', 'DuracionPrograma': 'C', 'TipoEmision': 'C', 'InteresPrevio': 'C', 'GeneroPrograma': 'C', 'PopularidadPrograma': 'C', 'Satisfaccion': 'C', 'Recomendado': 'C'}
# --- equivalent_sample_size = 50 ---
#   0%|          | 0/1000000 [00:00<?, ?it/s]
# INFO:pgmpy: Datatype (N=numerical, C=Categorical Unordered, O=Categorical Ordered) inferred from data:
#  {'GeneroUsuario': 'C', 'EdadUsuario': 'C', 'Hora': 'C', 'DiaSemana': 'C', 'DuracionPrograma': 'C', 'TipoEmision': 'C', 'InteresPrevio': 'C', 'GeneroPrograma': 'C', 'PopularidadPrograma': 'C', 'Satisfaccion': 'C', 'Recomendado': 'C'}
# Edges: [('GeneroUsuario', 'EdadUsuario'), ('Hora', 'TipoEmision'), ('DiaSemana', 'TipoEmision'), ('DuracionPrograma', 'GeneroPrograma'), ('TipoEmision', 'InteresPrevio'), ('TipoEmision', 'GeneroPrograma'), ('InteresPrevio', 'EdadUsuario'), ('InteresPrevio', 'GeneroUsuario'), ('InteresPrevio', 'PopularidadPrograma'), ('InteresPrevio', 'Satisfaccion'), ('InteresPrevio', 'GeneroPrograma'), ('GeneroPrograma', 'PopularidadPrograma'), ('GeneroPrograma', 'Satisfaccion'), ('PopularidadPrograma', 'Recomendado'), ('Satisfaccion', 'Recomendado'), ('Satisfaccion', 'PopularidadPrograma')]
# INFO:pgmpy: Datatype (N=numerical, C=Categorical Unordered, O=Categorical Ordered) inferred from data:
#  {'GeneroUsuario': 'C', 'EdadUsuario': 'C', 'Hora': 'C', 'DiaSemana': 'C', 'DuracionPrograma': 'C', 'TipoEmision': 'C', 'InteresPrevio': 'C', 'GeneroPrograma': 'C', 'PopularidadPrograma': 'C', 'Satisfaccion': 'C', 'Recomendado': 'C'}
# INFO:pgmpy: Datatype (N=numerical, C=Categorical Unordered, O=Categorical Ordered) inferred from data:
#  {'GeneroUsuario': 'C', 'EdadUsuario': 'C', 'Hora': 'C', 'DiaSemana': 'C', 'DuracionPrograma': 'C', 'TipoEmision': 'C', 'InteresPrevio': 'C', 'GeneroPrograma': 'C', 'PopularidadPrograma': 'C', 'Satisfaccion': 'C', 'Recomendado': 'C'}
# --- equivalent_sample_size = 100 ---
#   0%|          | 0/1000000 [00:00<?, ?it/s]
# INFO:pgmpy: Datatype (N=numerical, C=Categorical Unordered, O=Categorical Ordered) inferred from data:
#  {'GeneroUsuario': 'C', 'EdadUsuario': 'C', 'Hora': 'C', 'DiaSemana': 'C', 'DuracionPrograma': 'C', 'TipoEmision': 'C', 'InteresPrevio': 'C', 'GeneroPrograma': 'C', 'PopularidadPrograma': 'C', 'Satisfaccion': 'C', 'Recomendado': 'C'}
# Edges: [('GeneroUsuario', 'InteresPrevio'), ('EdadUsuario', 'InteresPrevio'), ('DiaSemana', 'Hora'), ('DiaSemana', 'TipoEmision'), ('DuracionPrograma', 'GeneroPrograma'), ('TipoEmision', 'Hora'), ('TipoEmision', 'GeneroPrograma'), ('InteresPrevio', 'GeneroPrograma'), ('InteresPrevio', 'PopularidadPrograma'), ('InteresPrevio', 'Satisfaccion'), ('GeneroPrograma', 'PopularidadPrograma'), ('GeneroPrograma', 'Satisfaccion'), ('PopularidadPrograma', 'Recomendado'), ('Satisfaccion', 'Recomendado'), ('Satisfaccion', 'PopularidadPrograma')]
# INFO:pgmpy: Datatype (N=numerical, C=Categorical Unordered, O=Categorical Ordered) inferred from data:
#  {'GeneroUsuario': 'C', 'EdadUsuario': 'C', 'Hora': 'C', 'DiaSemana': 'C', 'DuracionPrograma': 'C', 'TipoEmision': 'C', 'InteresPrevio': 'C', 'GeneroPrograma': 'C', 'PopularidadPrograma': 'C', 'Satisfaccion': 'C', 'Recomendado': 'C'}
# INFO:pgmpy: Datatype (N=numerical, C=Categorical Unordered, O=Categorical Ordered) inferred from data:
#  {'GeneroUsuario': 'C', 'EdadUsuario': 'C', 'Hora': 'C', 'DiaSemana': 'C', 'DuracionPrograma': 'C', 'TipoEmision': 'C', 'InteresPrevio': 'C', 'GeneroPrograma': 'C', 'PopularidadPrograma': 'C', 'Satisfaccion': 'C', 'Recomendado': 'C'}
# --- equivalent_sample_size = 500 ---
#   0%|          | 0/1000000 [00:00<?, ?it/s]
# INFO:pgmpy: Datatype (N=numerical, C=Categorical Unordered, O=Categorical Ordered) inferred from data:
#  {'GeneroUsuario': 'C', 'EdadUsuario': 'C', 'Hora': 'C', 'DiaSemana': 'C', 'DuracionPrograma': 'C', 'TipoEmision': 'C', 'InteresPrevio': 'C', 'GeneroPrograma': 'C', 'PopularidadPrograma': 'C', 'Satisfaccion': 'C', 'Recomendado': 'C'}
# Edges: [('GeneroUsuario', 'EdadUsuario'), ('DiaSemana', 'Hora'), ('DiaSemana', 'TipoEmision'), ('DuracionPrograma', 'GeneroPrograma'), ('DuracionPrograma', 'InteresPrevio'), ('DuracionPrograma', 'DiaSemana'), ('TipoEmision', 'Hora'), ('TipoEmision', 'InteresPrevio'), ('TipoEmision', 'GeneroPrograma'), ('InteresPrevio', 'EdadUsuario'), ('InteresPrevio', 'GeneroUsuario'), ('InteresPrevio', 'Satisfaccion'), ('GeneroPrograma', 'InteresPrevio'), ('GeneroPrograma', 'PopularidadPrograma'), ('GeneroPrograma', 'Satisfaccion'), ('PopularidadPrograma', 'Recomendado'), ('PopularidadPrograma', 'Satisfaccion'), ('Satisfaccion', 'Recomendado')]
